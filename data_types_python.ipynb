# %% [markdown]
# # data types in python
# 1. different va type of values assined to variable
# 2. basically 3 data types in python
# 3. int(integer) - numerical values like 1,2,3,....nt
# 4. str(string) - chareters example "abcd",'ghik',"qwerty"
# 5. float(decimals) - numerical with decimals - 10.25,100.25,25.35

# %%
name="vikas"
age=25
salary=100023.25
data="123"
print(name)
print(age)
print(salary)
print(data)
print(type(name))
print(type(age))
print(type(salary))
print(type(data))
# Out:
# vikas
# 25
# 100023.25
# 123
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# concatentions
a=100
b=200
print(a+b)
# Out:
# 300

# %%
n1="python"
n2="programming"
print(n1+n2)
# Out:
# pythonprogramming

# %%
a=100
b=300
print(a+b)
# Out:
# 400
