# %%
# variables in python
1. variable is memory allocation to a value
2.examples are name="shivaji",age=26,salary=10000.55

#key points to define variable
1.do not start with digit while creating variable
2.does not allow special characters in a variable
3.do not use keywords as a variable

# %%
name="vikas"
age=26
salary=10000.55
print(name)
print(age)
print(salary)
# Out:
# vikas
# 26
# 10000.55

# %%
name="vikas"
print(name)
# Out:
# vikas
