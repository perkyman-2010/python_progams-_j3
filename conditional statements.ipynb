# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional statements
# 2. `if` statement
# 3. `else`statement
# 4. `elif` statement
# 5. `nested` statement
#
# ```python
# if(condition):
#     statements
#     statenents..
#     ```
#  ```python if,else
# if(condition):
#               statements
#               statements...
# else:
#     statements
#     statements...
#  ```
#
#  ```python if,else.elif
#  if(condition)
#     statement
#  elif(condition):
#      statements
#  elif(condition):
#  else:
#        statements..
# ```

# %%
#write a program to find the given number is even number
num=int(input("please enter number here:"))
if(num%2==0):
    print(num,"is even number")
# Out:
# please enter number here: 123

# %%
#write a program to find the given number is even number or odd number
number = int(input("please enter number here:"))
if(number%2 == 0):
    print(number,"is even number")
else:
    print(number,"is odd number")
# Out:
# please enter number here: 24689
# 24689 is odd number

# %%
#write a program to find positve number is positive or negitive or zero
number = int(input("please enter number here:"))
if(number > 0):
    print(number,"is positive number")
elif(number < 0):
    print(number,"is negitive number")
else:
    print(number,"is zero number")
# Out:
# please enter number here: 0
# 0 is zero number

# %%
"""
write a program to find the student grades based on marks
1. if student marks in between 100 to 80 then grade is A
2. if student marks in between 79 to 60 then grade is B
3. if student marks in between 59 to 40 then grade is C
4. if student marks in between 39 to 25 then grade is D
5. if student marks in between 24 to 0 then grade is Fail
6. if other than above marks expected output should be please enter correct marks!
"""
marks=int(input("enter student marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"is A grade")
elif (marks>=60 and marks<=79):
    print(marks,"is B grade")
elif (marks>=40 and marks<=59):
    print(marks,"is C grade")
elif (marks>=25 and marks<=39):
     print(marks,"is D grade")
elif (marks>=0 and marks<=24):
    print(marks," is Fail")
else:
    print(marks,"is not correct marks, please enter correct marks")
# Out:
# enter student marks here: 92
# 92 is A grade

# %%
# write a program to find the largfest number from three numbers
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3
print("The largest number is:", largest)
# Out:
# Enter first number:  22
# Enter second number:  12
# Enter third number:  35
# The largest number is: 35.0

# %%
# write a program to find the leap year or non leap year
year = int(input("Enter a year: "))
if (year % 4 == 0):
    if (year % 100 == 0):
        if (year % 400 == 0):
            print(year, "is a leap year.")
        else:
            print(year, "is not a leap year.")
    else:
        print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# Enter a year:  2050
# 2050 is not a leap year.

# %%
write a program to check login credentials using control statements 
correct_username = "admin"
correct_password = "12345"
if username == correct_username:
    if password == correct_password:
        print("Login successful!")
    else:
        print("Incorrect password.")
else:
    print("Username not found.")
# Out:
# Username not found.
